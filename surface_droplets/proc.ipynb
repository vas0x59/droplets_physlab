# %%
import numpy as np
import pickle 
from datetime import datetime

# %%
def load_data(path):
    res = pickle.load(open(path, "rb"))
    Rs = np.array([i[1] for i in res])
    Ts = np.array([datetime.strptime(i[0].split("_")[-1].split(".")[0], "%H%M%S").timestamp() for i in res])
    Ts = Ts - Ts[0]
    return Ts, Rs

# %%
d^a = d0^a - ct

# %%
d^a - d0^a = -ct

# %%
log(d) = a*log(d0 - ct)

# %%
log(d) = a*log(d0 - ct)

# %%
log(d0 - ct)

# %%
c =

# %%
plt.plot(Ts, np.log(Rs))

# %%
for i in ["d2_1_b13_res.pickle", "d2_2_res.pickle", "d2_3_res.pickle", "d2_4_b15_res.pickle", "d2_5_b13_wet_res.pickle", "d1_1_res.pickle", "d1_2_res.pickle", "d1_3_res.pickle", "d1_4_res.pickle"]:
    Ts, Rs = load_data(i)
    plt.plot(Ts, np.power(Rs, 2), label=i)
    # plt.plot(np.log(Ts), np.log(Rs), label=i)

plt.legend()
