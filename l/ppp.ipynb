# %%
import pickle

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ab_s = np.array(pickle.load(open("./ab_s.pickle", "rb")))

# %%
from scipy.signal import medfilt

# %%
a = medfilt(np.power(ab_s[:, 1]*ab_s[:, 1]*ab_s[:, 2], 1/3), 21)

# %%
# plt.plot(ab_s[:, 0], np.log(a - a[650]))

# %%
plt.plot(ab_s[:, 0], (ab_s[:, 1]))
