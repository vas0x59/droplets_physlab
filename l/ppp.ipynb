# %%
import pickle 
ab_s = pickle.load(open("./ab_s.pickle", "rb"))

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ab_s = np.array(ab_s)

# %%
from scipy.signal import medfilt

# %%
plt.plot(medfilt(ab_s[:, 1], 21)**3/2)
