# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from list_experiments import   list_experiments

# %%
# T_20 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/68/20/Rs.npy"), 1)
T_19 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/68/19/Rs.npy"), 1)/150
T_18 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/68/18/Rs.npy"), 1)/150
T_17 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/68/17/Rs.npy"), 1)/150
T_16 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/68/16/Rs.npy"), 1)/150
# T_wo2 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/4 without/Rs.npy"), 1)
# T32_p2 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/18/Rs.npy"), 1)
# T32_p1 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/19/Rs.npy"), 1)

# %%
density = True
plt.hist(T_19, bins=np.linspace(0,100, 50)/150, density=density, color="g", alpha=0.5, label="19", histtype=u'step', linewidth=2)
plt.hist(T_18, bins=np.linspace(0,100, 50)/150, density=density, color="k", alpha=0.5, label="18", histtype=u'step', linewidth=2)
plt.hist(T_17, bins=np.linspace(0,100, 50)/150, density=density, color="b", alpha=0.5, label="17", histtype=u'step', linewidth=2)
plt.hist(T_16, bins=np.linspace(0,100, 50)/150, density=density, color="r", alpha=0.5, label="16", histtype=u'step', linewidth=2)
plt.legend()

# %%
import glob

# %%
import scipy.stats

# %%
density = True

for path in sorted(glob.glob("/Users/vasily/Downloads/Telegram Desktop/68" + "/*")): 
    T = np.load(path + "/Rs.npy")
    # plt.hist(T, bins=np.linspace(0,100, 50), density=density, alpha=0.5, label=path.split("/")[-1], histtype=u'step', linewidth=2)
    Ds = np.linspace(0,100, 40)
    N = len(list_experiments(path))
    print(N, len(T), np.mean(np.power(T, 1)), np.mean(np.power(T, 2)), np.mean(np.power(T, 2)),"d32=", np.mean(np.power(T, 3))/np.mean(np.power(T, 2)))
    nds = np.histogram(T, Ds)[0] / N
    # print()
    plt.step(Ds[1:], nds, label=path.split("/")[-1])
    plt.legend()
# Out:
# 4 4566 18.07394153005092 493.19316688567676 493.19316688567676 d32= 40.213172877592335
# 4 5885 19.69942753856789 607.9021240441801 607.9021240441801 d32= 45.03061328371437
# 4 9047 20.922602422539665 656.9369956891787 656.9369956891787 d32= 43.75771500928036
# 4 10456 23.269849445355042 810.3491775057383 810.3491775057383 d32= 49.028963003260394
# 4 6083 22.503378244233865 722.1043892816044 722.1043892816044 d32= 44.74005993160338

# %%
density = True
means = []
for path in sorted(glob.glob("/Users/vasily/Documents/droplets/untitled folder" + "/*")): 
    try:
        T = np.load(path + "/Rs.npy")
        # plt.hist(T, bins=np.l inspace(0,100, 50), density=density, alpha=0.5, label=path.split("/")[-1], histtype=u'step', linewidth=2)
        Ds = np.linspace(0,400, 50)
        N = len(list_experiments(path))
        print(N, path, len(T), np.mean(np.power(T, 1)), np.mean(np.power(T, 2)), np.mean(np.power(T, 2)),"d32=", np.mean(np.power(T, 3))/np.mean(np.power(T, 2)))
        nds = np.histogram(T, Ds)[0] 
        # print()
        plt.step(Ds[1:], nds, label=path.split("/")[-1])
        plt.legend()
    except:
        pass
# Out:
# 10 /Users/vasily/Documents/droplets/untitled folder/big_data 779 138.85496116565866 24092.813863928113 24092.813863928113 d32= 194.17246738189874

# %%
density = True

for path in ["/Users/vasily/Downloads/Telegram Desktop/3 with", "/Users/vasily/Downloads/Telegram Desktop/3 without", "/Users/vasily/Downloads/Telegram Desktop/4 without"]: 
    T = np.load(path + "/Rs.npy")
    Ds = np.linspace(0,100, 50)
    nds = np.histogram(T, Ds)[0] / len(list_experiments(path))
    # print()
    print(path, np.mean(np.power(T, 1)), np.mean(np.power(T, 2)), np.mean(np.power(T, 2)),"d32=", np.mean(np.power(T, 3))/np.mean(np.power(T, 2)))
    # plt.step(Ds[1:], nds, label=path.split("/")[-1])
    plt.hist(T, bins=np.linspace(0,100, 50), density=density, alpha=0.7, label=path.split("/")[-1], histtype=u'step', linewidth=2)

    plt.legend()
# Out:
# /Users/vasily/Downloads/Telegram Desktop/3 with 17.67139612647654 483.82306855277477 483.82306855277477 d32= 41.20152355989903
# /Users/vasily/Downloads/Telegram Desktop/3 without 15.829764396065414 404.703920421299 404.703920421299 d32= 41.51780062496524
# /Users/vasily/Downloads/Telegram Desktop/4 without 14.162972183546193 318.3353804162402 318.3353804162402 d32= 36.18279834691723

# %% [markdown]
# [
#     np.mean(T_19),
#     np.mean(T_18),
#     np.mean(T_17),
#     np.mean(T_16),
# ]

# %%
# T_20 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/68/20/Rs.npy"), 1)
T_19 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/45/19/Rs.npy"), 1)
T_18 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/45/18/Rs.npy"), 1)
T_17 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/45/17/Rs.npy"), 1)
T_16 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/45/16/Rs.npy"), 1)
# T_wo2 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/4 without/Rs.npy"), 1)
# T32_p2 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/18/Rs.npy"), 1)
# T32_p1 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/19/Rs.npy"), 1)

# %%
# density = True

plt.hist(T_19, bins=np.linspace(0,100, 50), density=density, color="g", alpha=0.5, label="19", histtype=u'step', linewidth=2)
plt.hist(T_18, bins=np.linspace(0,100, 50), density=density, color="k", alpha=0.5, label="18", histtype=u'step', linewidth=2)
plt.hist(T_17, bins=np.linspace(0,100, 50), density=density, color="b", alpha=0.5, label="17", histtype=u'step', linewidth=2)
plt.hist(T_16, bins=np.linspace(0,100, 50), density=density, color="r", alpha=0.5, label="16", histtype=u'step', linewidth=2)
plt.legend()

# %%
[
    np.mean(T_19),
    np.mean(T_18),
    np.mean(T_17),
    np.mean(T_16),
]
# Out:
# [22.63825311691967, 18.062492580380557, 16.83086620878909, 16.12576853005333]

# %%
plt.hist(T_wo1, bins=np.linspace(0,100, 50), density=True, color="g", alpha=0.5)
plt.hist(T_wo2, bins=np.linspace(0,100, 50), density=True, color="r", alpha=0.5)
# Out:
# (array([0.        , 0.00033436, 0.02674855, 0.09345275, 0.10665984,
#         0.08175026, 0.04714432, 0.02858751, 0.01872398, 0.01437735,
#         0.01103378, 0.00769021, 0.00651996, 0.00417946, 0.00534971,
#         0.00367793, 0.00401228, 0.00284203, 0.00351075, 0.00217332,
#         0.0023405 , 0.00183896, 0.00300921, 0.00217332, 0.00217332,
#         0.00150461, 0.00066871, 0.00083589, 0.00100307, 0.00083589,
#         0.00100307, 0.00066871, 0.00016718, 0.00083589, 0.00050154,
#         0.00033436, 0.00033436, 0.00016718, 0.        , 0.        ,
#         0.00016718, 0.00033436, 0.00016718, 0.00016718, 0.        ,
#         0.        , 0.        , 0.        , 0.        ]),
#  array([  0.        ,   2.04081633,   4.08163265,   6.12244898,
#           8.16326531,  10.20408163,  12.24489796,  14.28571429,
#          16.32653061,  18.36734694,  20.40816327,  22.44897959,
#          24.48979592,  26.53061224,  28.57142857,  30.6122449 ,
# ...

# %%
np.mean(T_w)
# Out:
# 17.67139612647654

# %%
np.mean(T_wo1)
# Out:
# 15.829764396065414

# %%
np.mean(T_wo2)
# Out:
# 14.162972183546193

# %%
T61_p2 = np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/61/18/Rs.npy"), 1)
T61_p1 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/61/19/Rs.npy"), 1)
T32_p2 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/18/Rs.npy"), 1)
T32_p1 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/19/Rs.npy"), 1)

# %%
# T32_p2 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/18/Rs.npy"), 2)
# T32_p1 =  np.power(np.load("/Users/vasily/Downloads/Telegram Desktop/32/19/Rs.npy"), 2)

# %%
np.mean(T61_p1)
# Out:
# 19.941988384416394

# %%
np.mean(T32_p1)
# Out:
# 21.342180632362375

# %%
(np.mean(T61_p1) - np.mean(T61_p2))
# Out:
# 1.3665632727053598

# %%
(np.mean(T32_p1) - np.mean(T32_p2))
# Out:
# 0.8496913417422896

# %%
plt.hist(T61_p1, bins=np.linspace(0,100, 50), density=True, color="g", alpha=0.5)
plt.hist(T61_p2, bins=np.linspace(0,100, 50), density=True, color="r", alpha=0.5)
# Out:
# (array([0.00000000e+00, 3.59950048e-04, 1.09784765e-02, 5.43884522e-02,
#         8.82597517e-02, 7.08381694e-02, 5.41724822e-02, 3.69308749e-02,
#         2.41886432e-02, 2.06971277e-02, 1.59817821e-02, 1.30301917e-02,
#         1.06185264e-02, 8.35084111e-03, 7.70293102e-03, 7.30698597e-03,
#         5.68721075e-03, 6.58708587e-03, 5.03930067e-03, 5.29126570e-03,
#         4.64335562e-03, 4.24741056e-03, 3.77947550e-03, 3.49151546e-03,
#         3.16756042e-03, 2.80761037e-03, 2.30368031e-03, 2.23169030e-03,
#         2.12370528e-03, 2.08771028e-03, 1.79975024e-03, 1.33181518e-03,
#         1.29582017e-03, 1.22383016e-03, 1.43980019e-03, 9.71865129e-04,
#         7.19900095e-04, 6.11915081e-04, 6.11915081e-04, 4.67935062e-04,
#         4.31940057e-04, 3.95945053e-04, 3.95945053e-04, 2.87960038e-04,
#         2.87960038e-04, 1.07985014e-04, 2.15970029e-04, 3.59950048e-05,
#         7.19900095e-05]),
#  array([  0.        ,   2.04081633,   4.08163265,   6.12244898,
# ...

# %%
plt.hist(T32_p1, bins=np.linspace(0,100, 50), density=True, color="g", alpha=0.5)
plt.hist(T32_p2, bins=np.linspace(0,100, 50), density=True, color="r", alpha=0.5)
# Out:
# (array([0.        , 0.00010823, 0.00825235, 0.04591552, 0.08365986,
#         0.06975262, 0.0500011 , 0.03457869, 0.02721922, 0.02013031,
#         0.01558476, 0.01480011, 0.01222971, 0.00944285, 0.00838763,
#         0.00798178, 0.0070889 , 0.0067101 , 0.00638542, 0.00538432,
#         0.00541137, 0.00492435, 0.00462673, 0.00468084, 0.00419382,
#         0.00351739, 0.00303037, 0.00303037, 0.00262452, 0.00240806,
#         0.00178575, 0.00216455, 0.00173164, 0.00154224, 0.00148813,
#         0.00129873, 0.00102816, 0.0011905 , 0.00091993, 0.00094699,
#         0.00078465, 0.00078465, 0.00035174, 0.0003788 , 0.00048702,
#         0.00029763, 0.00032468, 0.00024351, 0.0001894 ]),
#  array([  0.        ,   2.04081633,   4.08163265,   6.12244898,
#           8.16326531,  10.20408163,  12.24489796,  14.28571429,
#          16.32653061,  18.36734694,  20.40816327,  22.44897959,
#          24.48979592,  26.53061224,  28.57142857,  30.6122449 ,
# ...

# %%
plt.hist(T61_p2, bins=np.linspace(0,100, 50), density=True, color="g", alpha=0.5)
plt.hist(T32_p2, bins=np.linspace(0,100, 50), density=True, color="r", alpha=0.5)
# Out:
# (array([0.        , 0.00010823, 0.00825235, 0.04591552, 0.08365986,
#         0.06975262, 0.0500011 , 0.03457869, 0.02721922, 0.02013031,
#         0.01558476, 0.01480011, 0.01222971, 0.00944285, 0.00838763,
#         0.00798178, 0.0070889 , 0.0067101 , 0.00638542, 0.00538432,
#         0.00541137, 0.00492435, 0.00462673, 0.00468084, 0.00419382,
#         0.00351739, 0.00303037, 0.00303037, 0.00262452, 0.00240806,
#         0.00178575, 0.00216455, 0.00173164, 0.00154224, 0.00148813,
#         0.00129873, 0.00102816, 0.0011905 , 0.00091993, 0.00094699,
#         0.00078465, 0.00078465, 0.00035174, 0.0003788 , 0.00048702,
#         0.00029763, 0.00032468, 0.00024351, 0.0001894 ]),
#  array([  0.        ,   2.04081633,   4.08163265,   6.12244898,
#           8.16326531,  10.20408163,  12.24489796,  14.28571429,
#          16.32653061,  18.36734694,  20.40816327,  22.44897959,
#          24.48979592,  26.53061224,  28.57142857,  30.6122449 ,
# ...

# %%
plt.hist(T61_p1, bins=np.linspace(0,100, 50), density=True, color="g", alpha=0.5)
plt.hist(T32_p1, bins=np.linspace(0,100, 50), density=True, color="r", alpha=0.5)
# Out:
# (array([0.        , 0.00015379, 0.00719729, 0.04352206, 0.07357228,
#         0.06185362, 0.04616722, 0.0358019 , 0.0283893 , 0.02328354,
#         0.01913125, 0.01734731, 0.01454836, 0.01178018, 0.01048836,
#         0.00870441, 0.00861214, 0.00812002, 0.00787396, 0.00692047,
#         0.00538259, 0.00516728, 0.00489047, 0.00504425, 0.00390622,
#         0.00270667, 0.00313728, 0.00307576, 0.0028297 , 0.0023991 ,
#         0.00227607, 0.00203   , 0.00153788, 0.00147637, 0.00212228,
#         0.00147637, 0.00086121, 0.00113803, 0.00061515, 0.00064591,
#         0.00095349, 0.00036909, 0.0005844 , 0.00061515, 0.00030758,
#         0.00024606, 0.00027682, 0.00018455, 0.00027682]),
#  array([  0.        ,   2.04081633,   4.08163265,   6.12244898,
#           8.16326531,  10.20408163,  12.24489796,  14.28571429,
#          16.32653061,  18.36734694,  20.40816327,  22.44897959,
#          24.48979592,  26.53061224,  28.57142857,  30.6122449 ,
# ...

# %%
D =
